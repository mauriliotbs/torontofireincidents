# %% [markdown]
# ### Hypothesis Testing
# Our objective is to assess the strength of associations between fire incidents and predict their impact based on various circumstances.
# This impact will be measured using dependent variables, which may include features such as the number of people displaced, fatalities, property damage, among others.
# The circumstances surrounding fire incidents will be evaluated and treated as independent variables, encompassing features such as the extent of fire, ignition source, property use, etc.
#
# We will examine whether the presence or absence of specific nominal features (categorized circumstances) can influence the outcome of continuous features (measured impact) of fire incidents.
#
# ### Methodology
# The point-biserial correlation coefficient will used as it provides a succint way to examine the strength of association between nominal and continous variables.
# Several other methods were also tested and can be found in the project repository.

# %% [markdown]
# #### Import Dependencies and Dataframe

# %%
from scipy.stats import pointbiserialr
from scipy.stats import f_oneway
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Import DF CSV File and import normalize

# %%
df = pd.read_csv('../../data/processed/numerical_encoded_Fire_Incidents_Data.csv')
df
# Out:
#        Area_of_Origin  Building_Status  Business_Impact  Civilian_Casualties  \
# 0                  56                0                0                  0.0
# 1                   6                0                0                  0.0
# 2                  36                0                1                  0.0
# 3                  12                0                0                  0.0
# 4                   8                0                5                  0.0
# ...               ...              ...              ...                  ...
# 15623              45                0                5                  1.0
# 15624              21                0                0                  1.0
# 15625              23                0                0                  1.0
# 15626              25                0                5                  1.0
# 15627              25                0                5                  1.0
#
#        Count_of_Persons_Rescued  Estimated_Dollar_Loss  \
# 0                             0                      0
# 1                             0                   2000
# 2                             0                 100000
# 3                             0                   5000
# 4                             0                    500
# ...                         ...                    ...
# 15623                         0                    200
# 15624                         0                      0
# 15625                         0                      0
# 15626                         0                   2000
# 15627                         0                      0
#
#        Estimated_Number_Of_Persons_Displaced  Exposures  \
# 0                                          0        0.0
# 1                                          0        0.4
# 2                                          0        1.0
# 3                                          0        0.2
# 4                                          0        0.0
# ...                                      ...        ...
# 15623                                      0        0.0
# 15624                                      0        0.0
# 15625                                      0        0.0
# 15626                                      0        0.0
# 15627                                      0        0.0
#
#       Ext_agent_app_or_defer_time  Extent_Of_Fire  ...  \
# 0             2018-02-25T14:19:25               0  ...
# 1             2018-02-26T18:28:00               3  ...
# 2             2018-02-27T10:57:32               3  ...
# 3             2018-02-25T15:57:00               0  ...
# 4             2018-02-26T18:16:50               0  ...
# ...                           ...             ...  ...
# 15623         2022-11-25T11:50:40              10  ...
# 15624         2022-11-25T19:56:00               0  ...
# 15625         2022-11-26T06:20:00               0  ...
# 15626         2022-11-26T08:32:05               3  ...
# 15627         2022-11-26T11:26:54               0  ...
#
#        Smoke_Alarm_at_Fire_Origin_Alarm_Failure  \
# 0                                             9
# 1                                             9
# 2                                             9
# 3                                             9
# 4                                             9
# ...                                         ...
# 15623                                         9
# 15624                                         9
# 15625                                         9
# 15626                                         9
# 15627                                         9
#
#        Smoke_Alarm_at_Fire_Origin_Alarm_Type  \
# 0                                          5
# 1                                          4
# 2                                          4
# 3                                          1
# 4                                          0
# ...                                      ...
# 15623                                      3
# 15624                                      5
# 15625                                      3
# 15626                                      3
# 15627                                      4
#
#        Smoke_Alarm_Impact_on_Persons_Evacuating_Impact_on_Evacuation  \
# 0                                                      5
# 1                                                      4
# 2                                                      1
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 15623                                                  2
# 15624                                                  5
# 15625                                                  2
# 15626                                                  5
# 15627                                                  1
#
#        Smoke_Spread Sprinkler_System_Operation  Sprinkler_System_Presence  \
# 0                 9                          5                          3
# 1                 1                          5                          2
# 2                 6                          5                          2
# 3                 3                          2                          0
# 4                 1                          5                          2
# ...             ...                        ...                        ...
# 15623             8                          5                          2
# 15624             1                          2                          3
# 15625             2                          2                          0
# 15626             3                          1                          0
# 15627             4                          0                          1
#
#       Status_of_Fire_On_Arrival       TFS_Alarm_Time     TFS_Arrival_Time  \
# 0                             2  2018-02-25T14:13:39  2018-02-25T14:18:07
# 1                             1  2018-02-26T18:18:55  2018-02-26T18:24:47
# 2                             1  2018-02-27T10:28:12  2018-02-27T10:35:13
# 3                             3  2018-02-25T15:48:34  2018-02-25T15:52:04
# 4                             0  2018-02-26T18:11:59  2018-02-26T18:15:50
# ...                         ...                  ...                  ...
# 15623                         2  2022-11-25T11:39:24  2022-11-25T11:45:01
# 15624                         0  2022-11-25T19:54:23  2022-11-25T19:55:52
# 15625                         1  2022-11-26T06:06:11  2022-11-26T06:12:09
# 15626                         1  2022-11-26T08:22:16  2022-11-26T08:26:04
# 15627                         0  2022-11-26T11:18:03  2022-11-26T11:25:11
#
#        TFS_Firefighter_Casualties
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 15623                           0
# 15624                           0
# 15625                           0
# 15626                           0
# 15627                           0
#
# [15628 rows x 42 columns]
